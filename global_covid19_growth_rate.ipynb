# %%
import functools
import glob
import os
import pandas as pd
import numpy as np

# %% [markdown]
# # Data

# %%
# CSSE data
data = pd.concat(map(functools.partial(pd.read_csv), glob.glob("data/csse_covid19_daily_reports/*.csv")), sort=True)

# %%
# Date col names changed at some point
country_cols = ['Country/Region', 'Country_Region']
data['Country'] = data[country_cols].apply(lambda x: ','.join(x.dropna()), axis=1)

# %%
# Country col names changed at some point
date_cols = ['Last Update', 'Last_Update']
data['Last_Updated'] = data[date_cols].apply(lambda x: ','.join(x.dropna()), axis=1)

# %%
# Region col names changed at some point
region_cols = ['Province/State', 'Province_State']
data['Province'] = data[region_cols].apply(lambda x: ','.join(x.dropna()), axis=1)

# %%
# Set date index
data = data.set_index(pd.DatetimeIndex(data['Last_Updated'])).sort_index() # Set ascending date

# %%
data.tail()
# Out:
#                      Active Admin2                             Combined_Key  \
# Last_Updated
# 2020-03-29 23:14:06    75.0    NaN  Australian Capital Territory, Australia
# 2020-03-29 23:14:06   293.0    NaN               South Australia, Australia
# 2020-03-29 23:14:06    61.0    NaN                      Tasmania, Australia
# 2020-03-29 23:14:06   574.0    NaN                      Victoria, Australia
# 2020-03-29 23:14:06   281.0    NaN             Western Australia, Australia
#
#                      Confirmed Country/Region Country_Region  Deaths  FIPS  \
# Last_Updated
# 2020-03-29 23:14:06       77.0            NaN      Australia     0.0   NaN
# 2020-03-29 23:14:06      299.0            NaN      Australia     0.0   NaN
# 2020-03-29 23:14:06       66.0            NaN      Australia     0.0   NaN
# 2020-03-29 23:14:06      769.0            NaN      Australia     4.0   NaN
# 2020-03-29 23:14:06      311.0            NaN      Australia     2.0   NaN
#
#                     Last Update          Last_Update      Lat  Latitude  \
# Last_Updated
# 2020-03-29 23:14:06         NaN  2020-03-29 23:14:06 -35.4735       NaN
# 2020-03-29 23:14:06         NaN  2020-03-29 23:14:06 -34.9285       NaN
# 2020-03-29 23:14:06         NaN  2020-03-29 23:14:06 -42.8821       NaN
# 2020-03-29 23:14:06         NaN  2020-03-29 23:14:06 -37.8136       NaN
# 2020-03-29 23:14:06         NaN  2020-03-29 23:14:06 -31.9505       NaN
#
#                         Long_  Longitude Province/State  \
# Last_Updated
# 2020-03-29 23:14:06  149.0124        NaN            NaN
# 2020-03-29 23:14:06  138.6007        NaN            NaN
# 2020-03-29 23:14:06  147.3272        NaN            NaN
# 2020-03-29 23:14:06  144.9631        NaN            NaN
# 2020-03-29 23:14:06  115.8605        NaN            NaN
#
#                                    Province_State  Recovered    Country  \
# Last_Updated
# 2020-03-29 23:14:06  Australian Capital Territory        2.0  Australia
# 2020-03-29 23:14:06               South Australia        6.0  Australia
# 2020-03-29 23:14:06                      Tasmania        5.0  Australia
# 2020-03-29 23:14:06                      Victoria      191.0  Australia
# 2020-03-29 23:14:06             Western Australia       28.0  Australia
#
#                             Last_Updated                      Province
# Last_Updated
# 2020-03-29 23:14:06  2020-03-29 23:14:06  Australian Capital Territory
# 2020-03-29 23:14:06  2020-03-29 23:14:06               South Australia
# 2020-03-29 23:14:06  2020-03-29 23:14:06                      Tasmania
# 2020-03-29 23:14:06  2020-03-29 23:14:06                      Victoria
# 2020-03-29 23:14:06  2020-03-29 23:14:06             Western Australia

# %%
#data['Country/Region'].unique()

# %% [markdown]
# # Countries for viz

# %%
# Select countries for comparison
df = data[data['Country'].isin(['Mainland China', 'South Korea', 'Italy', 'US', 'Mexico'])]

# %%
# Check last update in Mexico
df[df['Country'] == 'Mexico'].tail()
# Out:
#                      Active Admin2 Combined_Key  Confirmed Country/Region  \
# Last_Updated
# 2020-03-25 23:33:04   396.0    NaN       Mexico      405.0            NaN
# 2020-03-26 23:48:18   465.0    NaN       Mexico      475.0            NaN
# 2020-03-27 23:23:03   573.0    NaN       Mexico      585.0            NaN
# 2020-03-28 23:05:25   701.0    NaN       Mexico      717.0            NaN
# 2020-03-29 23:08:13   828.0    NaN       Mexico      848.0            NaN
#
#                     Country_Region  Deaths  FIPS Last Update  \
# Last_Updated
# 2020-03-25 23:33:04         Mexico     5.0   NaN         NaN
# 2020-03-26 23:48:18         Mexico     6.0   NaN         NaN
# 2020-03-27 23:23:03         Mexico     8.0   NaN         NaN
# 2020-03-28 23:05:25         Mexico    12.0   NaN         NaN
# 2020-03-29 23:08:13         Mexico    16.0   NaN         NaN
#
#                              Last_Update      Lat  Latitude     Long_  \
# Last_Updated
# 2020-03-25 23:33:04  2020-03-25 23:33:04  23.6345       NaN -102.5528
# 2020-03-26 23:48:18  2020-03-26 23:48:18  23.6345       NaN -102.5528
# 2020-03-27 23:23:03  2020-03-27 23:23:03  23.6345       NaN -102.5528
# 2020-03-28 23:05:25  2020-03-28 23:05:25  23.6345       NaN -102.5528
# 2020-03-29 23:08:13  2020-03-29 23:08:13  23.6345       NaN -102.5528
#
#                      Longitude Province/State Province_State  Recovered  \
# Last_Updated
# 2020-03-25 23:33:04        NaN            NaN            NaN        4.0
# 2020-03-26 23:48:18        NaN            NaN            NaN        4.0
# 2020-03-27 23:23:03        NaN            NaN            NaN        4.0
# 2020-03-28 23:05:25        NaN            NaN            NaN        4.0
# 2020-03-29 23:08:13        NaN            NaN            NaN        4.0
#
#                     Country         Last_Updated Province
# Last_Updated
# 2020-03-25 23:33:04  Mexico  2020-03-25 23:33:04
# 2020-03-26 23:48:18  Mexico  2020-03-26 23:48:18
# 2020-03-27 23:23:03  Mexico  2020-03-27 23:23:03
# 2020-03-28 23:05:25  Mexico  2020-03-28 23:05:25
# 2020-03-29 23:08:13  Mexico  2020-03-29 23:08:13

# %%
# Keep these columns
df = df[['Confirmed', 'Country', 'Province']]
df
# Out:
#                      Confirmed         Country     Province
# Last_Updated
# 2020-01-22 17:00:00        4.0  Mainland China        Hunan
# 2020-01-22 17:00:00        1.0  Mainland China      Ningxia
# 2020-01-22 17:00:00        NaN  Mainland China      Shaanxi
# 2020-01-22 17:00:00        2.0  Mainland China     Shandong
# 2020-01-22 17:00:00        9.0  Mainland China     Shanghai
# ...                        ...             ...          ...
# 2020-03-29 23:08:25      120.0              US     Oklahoma
# 2020-03-29 23:08:25        3.0              US     Oklahoma
# 2020-03-29 23:08:25        0.0              US      Florida
# 2020-03-29 23:08:25        3.0              US     Kentucky
# 2020-03-29 23:08:25       15.0              US  Mississippi
#
# [28643 rows x 3 columns]
