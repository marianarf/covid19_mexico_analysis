# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # COVID-19 data

# %%
totals = pd.read_csv('output_data/time_series/totals.csv')
daily = pd.read_csv('output_data/time_series/daily.csv')
