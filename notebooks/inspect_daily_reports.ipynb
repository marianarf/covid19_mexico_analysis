# %%
# Fase 3 makes it unclear how 'USMER' and 'Red IRAG' are going to work to report data
# https://www.gob.mx/presidencia/articulos/version-estenografica-conferencia-de-prensa-informe-diario-sobre-coronavirus-covid-19-en-mexico-241493

# %%
import pandas as pd

# %%
# !ls
# Out:
# 1_quick_process.R           _old
# 2_long_time_series.ipynb    inspect_daily_reports.ipynb

# %%
data_1 = pd.read_csv('../data/dge/200503COVID19MEXICO.csv', encoding='latin-1')

# %%
data_2 = pd.read_csv('../data/dge/200504COVID19MEXICO.csv', encoding='latin-1')

# %%
data = pd.concat([data_1, data_2])

# %%
print(data.set_index(['ID_REGISTRO']).index.is_unique) # ids are not unique... it's unclear how reports are aggregated
# Out:
# False

# %%
import janitor

# %%
#data = pd.read_csv('../latest.csv')

# %%
#data['Date_Confirmed'] = pd.to_datetime(data.Date_Confirmed, format='%Y-%m-%d')
#data['Date_Confirmed'] = data['Date_Confirmed'].dt.strftime('%Y-%m-%d')

# %%
data = data.filter_date('FECHA_ACTUALIZACION','2020-02-01','2020-05-01')

# %%
#len(data)

# %%
data
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-05-04      1ab4e5       2       3          25     2
# 1               2020-05-04      0cc140       2       3          15     1
# 2               2020-05-04      0e0689       2       3          27     1
# 3               2020-05-04      1b81dc       2       3           2     1
# 4               2020-05-04      0b7b4d       2       3          27     2
# ...                    ...         ...     ...     ...         ...   ...
# 100036          2020-05-04      1ce1b9       1      12           9     1
# 100037          2020-05-04      0f2dd8       1      13          21     1
# 100038          2020-05-04      02995d       1      13          21     1
# 100039          2020-05-04      048b5f       1      13          21     1
# 100040          2020-05-04      026940       1      13          21     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
data[data['RESULTADO']==1]
# Out:
#       FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0              2020-05-04      1ab4e5       2       3          25     2
# 1              2020-05-04      0cc140       2       3          15     1
# 2              2020-05-04      0e0689       2       3          27     1
# 3              2020-05-04      1b81dc       2       3           2     1
# 4              2020-05-04      0b7b4d       2       3          27     2
# ...                   ...         ...     ...     ...         ...   ...
# 30941          2020-05-04      146b5b       1      13          21     1
# 30942          2020-05-04      1ca23c       1      13          21     1
# 30943          2020-05-04      19adbb       1      13          19     1
# 30944          2020-05-04      0e7853       1      13          21     1
# 30945          2020-05-04      0108cf       1      13          21     1
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# ...

# %%
len(data[data['RESULTADO']!=1])+len(data[data['RESULTADO']==1])
# Out:
# 100041

# %%
# positive (==1)
pos = (len(data[data['RESULTADO']==1]))/len(data)
print(pos)

# %%
# negative (==2)
neg = (len(data)-len(data[data['RESULTADO']==2]))/len(data)
print(neg)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RESULTADO'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-423f6b87d414> in <module>
#       1 # negative (==2)
# ...

# %%
# not 1
len(data[data['RESULTADO']!=1])
# Out:
# 72368
